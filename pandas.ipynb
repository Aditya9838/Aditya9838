# %% [markdown]
# <a href="https://colab.research.google.com/github/Aditya9838/Aditya9838/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Series in pandas

# %%
s=pd.Series([10,20,30,40])

# %%
print(s)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %% [markdown]
# 2.with index

# %%
import pandas as pd
import numpy as np

# %%
s=pd.Series([10,20,30,40],index=["a","b","c","d"])

# %%
print(s)
# Out:
# a    10
# b    20
# c    30
# d    40
# dtype: int64

# %% [markdown]
# 3.series from dictionary

# %%
import pandas as pd
import numpy as np

# %%
data={"Math":90,"Physics":85,"Chemistry":88}

# %%
marks=pd.Series(data)

# %%
print(data)
# Out:
# {'Math': 90, 'Physics': 85, 'Chemistry': 88}

# %%
print(marks)
# Out:
# Math         90
# Physics      85
# Chemistry    88
# dtype: int64

# %% [markdown]
# 4.dataframe in pandas

# %%
import  pandas as pd
import numpy as np

# %%
data={
    "Name":["Aman","krish","Karan"],
    "Age":[22,23,21],
    "Marks":[85,90,88]
}

# %%
print(data)
# Out:
# {'Name': ['Aman', 'krish', 'Karan'], 'Age': [22, 23, 21], 'Marks': [85, 90, 88]}

# %%
type(data)
# Out:
# dict

# %%
marks=pd.DataFrame(data)

# %%
print(marks)
# Out:
#     Name  Age  Marks
# 0   Aman   22     85
# 1  krish   23     90
# 2  Karan   21     88

# %%
marks=pd.DataFrame(
    data,
    index=["Student1","Student2","Student3"]
)

# %%
print(marks)
# Out:
#            Name  Age  Marks
# Student1   Aman   22     85
# Student2  krish   23     90
# Student3  Karan   21     88

# %%
marks.set_index("Name",inplace=True) #if we are setting inplace=true it means we are changing orignal object itself

# %%
print(marks)
# Out:
#        Age  Marks
# Name
# Aman    22     85
# krish   23     90
# Karan   21     88

# %%
df=pd.DataFrame({
    "Name":["Aman","saurabh","Karan"],
    "Age":[22,23,21],
    "Marks":[85,90,88]
})

# %%
print(df)
# Out:
#       Name  Age  Marks
# 0     Aman   22     85
# 1  saurabh   23     90
# 2    Karan   21     88

# %%
df.head()  #as the no of rows are less than 5 so the output of both df head if more than 5 than first 5 will be printed
# Out:
#       Name  Age  Marks
# 0     Aman   22     85
# 1  saurabh   23     90
# 2    Karan   21     88

# %%
df.tail()   #less than 5 so all otherwise last 5 is printed
# Out:
#       Name  Age  Marks
# 0     Aman   22     85
# 1  saurabh   23     90
# 2    Karan   21     88

# %%
df=pd.DataFrame({"Name":["Aman","Saurav","Karan","Dinesh","Raj","abhishek"],
                 "Age":[22,23,43,78,21,24],
                 "Marks":[84,85,88,100,90,92]})

# %%
df.head(4)
# Out:
#      Name  Age  Marks
# 0    Aman   22     84
# 1  Saurav   23     85
# 2   Karan   43     88
# 3  Dinesh   78    100

# %%
df.tail(4)
# Out:
#        Name  Age  Marks
# 2     Karan   43     88
# 3    Dinesh   78    100
# 4       Raj   21     90
# 5  abhishek   24     92

# %%
df.shape
# Out:
# (6, 3)

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Marks'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    6 non-null      object
#  1   Age     6 non-null      int64
#  2   Marks   6 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 276.0+ bytes

# %%
df.describe()      #all data info mean median percent 50% 25%
# Out:
#              Age       Marks
# count   6.000000    6.000000
# mean   35.166667   89.833333
# std    22.551423    5.810909
# min    21.000000   84.000000
# 25%    22.250000   85.750000
# 50%    23.500000   89.000000
# 75%    38.250000   91.500000
# max    78.000000  100.000000

# %% [markdown]
# Selecting the data

# %%
df["Name"]
# Out:
# 0        Aman
# 1      Saurav
# 2       Karan
# 3      Dinesh
# 4         Raj
# 5    abhishek
# Name: Name, dtype: object

# %%
df[["Name","Marks"]]
# Out:
#        Name  Marks
# 0      Aman     84
# 1    Saurav     85
# 2     Karan     88
# 3    Dinesh    100
# 4       Raj     90
# 5  abhishek     92

# %% [markdown]
# Filtering in Pandas

# %%
df[df["Marks"]>85]    #outer df saying we want whole data
# Out:
#        Name  Age  Marks
# 2     Karan   43     88
# 3    Dinesh   78    100
# 4       Raj   21     90
# 5  abhishek   24     92

# %%
df[(df["Age"]>21)&(df["Marks"]>85)]
# Out:
#        Name  Age  Marks
# 2     Karan   43     88
# 3    Dinesh   78    100
# 5  abhishek   24     92

# %% [markdown]
# Sorting + Value Count

# %%
df.sort_values("Marks")
# Out:
#        Name  Age  Marks
# 0      Aman   22     84
# 1    Saurav   23     85
# 2     Karan   43     88
# 4       Raj   21     90
# 5  abhishek   24     92
# 3    Dinesh   78    100

# %%
df["Age"].value_counts()
# Out:
# Age
# 22    1
# 23    1
# 43    1
# 78    1
# 21    1
# 24    1
# Name: count, dtype: int64

# %% [markdown]
# handling missing value

# %%
df=pd.DataFrame({"Name":["Aman","saurav","Karan","shubham",None,"sameer"],"Age":[22,23,None,22,25,26],"marks":[85,None,88,90,56,None]})
df
# Out:
#       Name   Age  marks
# 0     Aman  22.0   85.0
# 1   saurav  23.0    NaN
# 2    Karan   NaN   88.0
# 3  shubham  22.0   90.0
# 4     None  25.0   56.0
# 5   sameer  26.0    NaN

# %%
df.isnull()   #checking the missing value
# Out:
#     Name    Age  marks
# 0  False  False  False
# 1  False  False   True
# 2  False   True  False
# 3  False  False  False
# 4   True  False  False
# 5  False  False   True

# %%
df.isnull().sum()    #count the nissing value
# Out:
# Name     1
# Age      1
# marks    2
# dtype: int64

# %%
df.dropna()
# Out:
#       Name   Age  marks
# 0     Aman  22.0   85.0
# 3  shubham  22.0   90.0

# %%
print(df)
# Out:
#       Name   Age  marks
# 0     Aman  22.0   85.0
# 1   saurav  23.0    NaN
# 2    Karan   NaN   88.0
# 3  shubham  22.0   90.0
# 4     None  25.0   56.0
# 5   sameer  26.0    NaN

# %% [markdown]
# excercise1:

# %%
df=pd.DataFrame({"Name":["aman","saurav","Karan","shubhum","abhishek",None,"Sameer"],
                 "Age":[22,23,None,22,25,24,26],
                 "Marks":[85,None,88,90,56,72,None],
                 "Subject":["Math","Physics","Math","Chemistry","Math","Physics","Chemistry"]})
df
# Out:
#        Name   Age  Marks    Subject
# 0      aman  22.0   85.0       Math
# 1    saurav  23.0    NaN    Physics
# 2     Karan   NaN   88.0       Math
# 3   shubhum  22.0   90.0  Chemistry
# 4  abhishek  25.0   56.0       Math
# 5      None  24.0   72.0    Physics
# 6    Sameer  26.0    NaN  Chemistry

# %%
df.shape
# Out:
# (7, 4)

# %%
df.dtypes
# Out:
# Name        object
# Age        float64
# Marks      float64
# Subject     object
# dtype: object

# %%
df.describe()
# Out:
#              Age      Marks
# count   6.000000   5.000000
# mean   23.666667  78.200000
# std     1.632993  14.254824
# min    22.000000  56.000000
# 25%    22.250000  72.000000
# 50%    23.500000  85.000000
# 75%    24.750000  88.000000
# max    26.000000  90.000000

# %% [markdown]
# selecting: view for name and marks

# %%
df[["Name","Marks"]]
# Out:
#        Name  Marks
# 0      aman   85.0
# 1    saurav    NaN
# 2     Karan   88.0
# 3   shubhum   90.0
# 4  abhishek   56.0
# 5      None   72.0
# 6    Sameer    NaN

# %% [markdown]
# scored >80

# %%
df[df["Marks"]>80]
# Out:
#       Name   Age  Marks    Subject
# 0     aman  22.0   85.0       Math
# 2    Karan   NaN   88.0       Math
# 3  shubhum  22.0   90.0  Chemistry

# %% [markdown]
# age>22 And marks>80

# %%
df[df["Age"]>22&(df["Marks"]>80)]
# Out:
#        Name   Age  Marks    Subject
# 0      aman  22.0   85.0       Math
# 1    saurav  23.0    NaN    Physics
# 3   shubhum  22.0   90.0  Chemistry
# 4  abhishek  25.0   56.0       Math
# 5      None  24.0   72.0    Physics
# 6    Sameer  26.0    NaN  Chemistry

# %% [markdown]
# count how muc stud enrolled in sub

# %%
df["Subject"].value_counts()
# Out:
# Subject
# Math         3
# Physics      2
# Chemistry    2
# Name: count, dtype: int64

# %% [markdown]
# sort by marks in decanding

# %%
df.sort_values(["Marks"], ascending=False)
# Out:
#        Name   Age  Marks    Subject
# 3   shubhum  22.0   90.0  Chemistry
# 2     Karan   NaN   88.0       Math
# 0      aman  22.0   85.0       Math
# 5      None  24.0   72.0    Physics
# 4  abhishek  25.0   56.0       Math
# 1    saurav  23.0    NaN    Physics
# 6    Sameer  26.0    NaN  Chemistry

# %% [markdown]
# find top 2 heighest marks without sorting whole dataframe

# %%
df.nlargest(2,"Marks")
# Out:
#       Name   Age  Marks    Subject
# 3  shubhum  22.0   90.0  Chemistry
# 2    Karan   NaN   88.0       Math

# %%
df.nsmallest(1,"Marks")
# Out:
#        Name   Age  Marks Subject
# 4  abhishek  25.0   56.0    Math

# %% [markdown]
# calcu total no. of missing values in each column

# %%
df.isnull().sum()
# Out:
# Name       1
# Age        1
# Marks      2
# Subject    0
# dtype: int64

# %% [markdown]
# marks are missing

# %% [markdown]
# 1.why uses float istead of integer?
